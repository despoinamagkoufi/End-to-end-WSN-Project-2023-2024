# %%
import pandas as pd

# %%
df = pd.read_csv('sensor_data.csv')

# %%
# Convert the 'timestamp' column to datetime
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Set the index to be the 'timestamp' column
df.set_index('timestamp', inplace=True)

# Resample the data to hourly averages
temperature_df_hourly = df['temperature'].resample('H').mean()
humidity_df_hourly = df['humidity'].resample('H').mean()

# Drop any missing values
temperature_df_hourly.dropna(inplace=True)
humidity_df_hourly.dropna(inplace=True)
# Display the first few rows
temperature_df_hourly.head()
# Out:
# timestamp
# 2024-09-27 18:00:00    30.127857
# 2024-09-27 20:00:00    28.535603
# 2024-09-27 21:00:00    28.144222
# 2024-09-27 22:00:00    27.984500
# 2024-09-27 23:00:00    27.931667
# Name: temperature, dtype: float64

# %%
# Import necessary packages
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# Split data into training and testing sets
train_size = int(len(temperature_df_hourly) * 0.7)
temperature_train = temperature_df_hourly[:train_size]
temperature_test = temperature_df_hourly[train_size:]

# %%
# Fit an ARIMA model
model = ARIMA(temperature_train, order=(5, 1, 0))
model_fit = model.fit()
# Make a forecast
forecast = model_fit.forecast(steps=len(temperature_test))
# Out:
# /home/angelos/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/angelos/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/angelos/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/angelos/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /home/angelos/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
# Plot actual vs predicted values
plt.plot(temperature_test.index, temperature_test, label='Actual')
plt.plot(temperature_test.index, forecast, label='Predicted')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add labels and legend
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.title('ARIMA - Actual vs Predicted Temperature')
plt.legend()

plt.tight_layout()

plt.show()

# Calculate metrics
mae = mean_absolute_error(temperature_test, forecast)
mse = mean_squared_error(temperature_test, forecast)
mape = mean_absolute_percentage_error(temperature_test, forecast)
print(f"ARIMA - MAE: {mae}, MSE: {mse}, MAPE: {mape}")
# Out:
# ARIMA - MAE: 2.2777785477196764, MSE: 5.784905241971222, MAPE: 0.08360662521862088

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
## Fit a SARIMAX model
model_sar = SARIMAX(temperature_train, order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
model_fit_sar = model_sar.fit()
# Out:
# /home/angelos/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/angelos/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /home/angelos/.local/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/angelos/.local/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/angelos/.local/lib/python3.8/site-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.73972D-01    |proj g|=  7.49549D-01
#
# At iterate    5    f=  3.83664D-01    |proj g|=  5.45700D-02
#
# At iterate   10    f=  3.78448D-01    |proj g|=  3.92591D-02
#
# At iterate   15    f=  3.72697D-01    |proj g|=  7.91036D-03
#
# At iterate   20    f=  3.72614D-01    |proj g|=  5.01022D-04
#
# At iterate   25    f=  3.72611D-01    |proj g|=  1.04052D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     25     35      1     0     0   1.041D-04   3.726D-01
#   F =  0.37261118486053341
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
# Forecast
forecast_sar = model_fit_sar.forecast(steps=len(temperature_test))
# Out:
# /home/angelos/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /home/angelos/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:836: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
 #Make a forecast
forecast = model_fit.forecast(steps=len(temperature_test))
# Out:
# /home/angelos/.local/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:836: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# Plot actual vs predicted values
plt.plot(temperature_test.index, temperature_test, label='Actual')
plt.plot(temperature_test.index, forecast_sar, label='Predicted')
# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add labels and legend
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.title('SARIMAX - Actual vs Predicted Temperature')

plt.legend()

plt.tight_layout()

plt.show()

# %%
# Calculate metrics
mae_sar = mean_absolute_error(temperature_test, forecast_sar)
mse_sar = mean_squared_error(temperature_test, forecast_sar)
mape_sar = mean_absolute_percentage_error(temperature_test, forecast_sar)
print(f"SARIMAX - MAE: {mae_sar}, MSE: {mse_sar}, MAPE: {mape_sar}")
# Out:
# SARIMAX - MAE: 1.3568779397354596, MSE: 2.2083670904184647, MAPE: 0.04989257037667431

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
# Normalize the temperature data
mean = temperature_df_hourly.mean()
std = temperature_df_hourly.std()
temperature_normalized = (temperature_df_hourly - mean) / std

# %%
# Create the LSTM input sequence
look_back = 24  # Use the last 24 hours
X = []
y = []
for i in range(look_back, len(temperature_normalized)):
    X.append(temperature_normalized[i - look_back:i])
    y.append(temperature_normalized[i])

X = np.array(X)
y = np.array(y)

# %%
# Split the data into training and testing sets
train_size = int(len(X) * 0.7)
X_train, y_train = X[:train_size], y[:train_size]
X_test, y_test = X[train_size:], y[train_size:]

# Reshape the input data for the LSTM model
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
# Define the LSTM model
model = Sequential()
model.add(LSTM(50, input_shape=(look_back, 1)))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Train the model
model.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 2s 2s/step - loss: 0.7527
# Epoch 2/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.7338
# Epoch 3/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.7160
# Epoch 4/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.6991
# Epoch 5/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.6829
# Epoch 6/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.6674
# Epoch 7/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.6523
# Epoch 8/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.6376
# Epoch 9/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.6231
# Epoch 10/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.6088
# Epoch 11/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.5946
# Epoch 12/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.5805
# Epoch 13/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.5664
# Epoch 14/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.5523
# Epoch 15/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.5381
# Epoch 16/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.5239
# Epoch 17/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.5095
# Epoch 18/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.4950
# Epoch 19/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.4802
# Epoch 20/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.4651
# Epoch 21/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.4496
# Epoch 22/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.4337
# Epoch 23/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.4171
# Epoch 24/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.4000
# Epoch 25/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3822
# Epoch 26/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3639
# Epoch 27/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.3455
# Epoch 28/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3275
# Epoch 29/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.3103
# Epoch 30/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.2948
# Epoch 31/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2818
# Epoch 32/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.2716
# Epoch 33/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.2639
# Epoch 34/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2577
# Epoch 35/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.2522
# Epoch 36/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2481
# Epoch 37/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2470
# Epoch 38/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2469
# Epoch 39/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2426
# Epoch 40/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2348
# Epoch 41/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.2277
# Epoch 42/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.2224
# Epoch 43/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.2166
# Epoch 44/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2095
# Epoch 45/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2024
# Epoch 46/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1969
# Epoch 47/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1929
# Epoch 48/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1899
# Epoch 49/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1886
# Epoch 50/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1879
# Epoch 51/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1849
# Epoch 52/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1798
# Epoch 53/100
# 1/1 [==============================] - 0s 45ms/step - loss: 0.1757
# Epoch 54/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1738
# Epoch 55/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1718
# Epoch 56/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1676
# Epoch 57/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.1624
# Epoch 58/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1587
# Epoch 59/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1570
# Epoch 60/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1541
# Epoch 61/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1506
# Epoch 62/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1479
# Epoch 63/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1459
# Epoch 64/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.1437
# Epoch 65/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.1396
# Epoch 66/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.1362
# Epoch 67/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.1338
# Epoch 68/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1295
# Epoch 69/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1257
# Epoch 70/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.1226
# Epoch 71/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.1198
# Epoch 72/100
# 1/1 [==============================] - 0s 37ms/step - loss: 0.1165
# Epoch 73/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1137
# Epoch 74/100
# 1/1 [==============================] - 0s 31ms/step - loss: 0.1118
# Epoch 75/100
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1090
# Epoch 76/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1066
# Epoch 77/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1045
# Epoch 78/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.1023
# Epoch 79/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0999
# Epoch 80/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0982
# Epoch 81/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0961
# Epoch 82/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0940
# Epoch 83/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0926
# Epoch 84/100
# 1/1 [==============================] - 0s 33ms/step - loss: 0.0907
# Epoch 85/100
# 1/1 [==============================] - 0s 39ms/step - loss: 0.0893
# Epoch 86/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0882
# Epoch 87/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0868
# Epoch 88/100
# 1/1 [==============================] - 0s 32ms/step - loss: 0.0860
# Epoch 89/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0851
# Epoch 90/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0842
# Epoch 91/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0835
# Epoch 92/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0827
# Epoch 93/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0822
# Epoch 94/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0816
# Epoch 95/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0811
# Epoch 96/100
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0805
# Epoch 97/100
# 1/1 [==============================] - 0s 38ms/step - loss: 0.0798
# Epoch 98/100
# 1/1 [==============================] - 0s 29ms/step - loss: 0.0792
# Epoch 99/100
# 1/1 [==============================] - 0s 25ms/step - loss: 0.0783
# Epoch 100/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0775

# %%
# Predict future values
forecast_lstm = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 275ms/step

# %%
# Denormalize the forecasted values
forecast_denormalized = forecast_lstm * std + mean
y_test_denormalized = y_test * std + mean

# Use the same index for plotting (so both y_test and forecast align)
time_index = temperature_df_hourly.index[-len(y_test):]

# Plot actual vs predicted values
plt.plot(time_index, y_test_denormalized, label='Actual')
plt.plot(time_index, forecast_denormalized, label='Predicted')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add labels and legend
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.title('LSTM - Actual vs Predicted Temperature')

plt.legend()

plt.tight_layout()
plt.show()

# %%
# Calculate metrics
mae_lstm = mean_absolute_error(y_test_denormalized, forecast_denormalized)
mse_lstm = mean_squared_error(y_test_denormalized, forecast_denormalized)
mape_lstm = mean_absolute_percentage_error(y_test_denormalized, forecast_denormalized)
print(f"LSTM - MAE: {mae_lstm}, MSE: {mse_lstm}, MAPE: {mape_lstm}")
# Out:
# LSTM - MAE: 0.4089096808345296, MSE: 0.21335368651083844, MAPE: 0.015088440547516208

# %%
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

 #Normalize the temperature data
mean = temperature_df_hourly.mean()
std = temperature_df_hourly.std()
temperature_normalized = (temperature_df_hourly - mean) / std

# %%
# Create the RNN input sequence
look_back = 24  # Use the last 24 hours
X = []
y = []
for i in range(look_back, len(temperature_normalized)):
    X.append(temperature_normalized[i - look_back:i])
    y.append(temperature_normalized[i])

# %%
X = np.array(X)
y = np.array(y)

# Split the data into training and testing sets
train_size = int(len(X) * 0.7)
X_train, y_train = X[:train_size], y[:train_size]
X_test, y_test = X[train_size:], y[train_size:]

# Reshape the input data for the RNN model
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
# Define the SimpleRNN model
model = Sequential()
model.add(SimpleRNN(50, input_shape=(look_back, 1)))  # Replaced LSTM with SimpleRNN
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# Fit the model
model.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 1/1 [==============================] - 1s 658ms/step - loss: 0.3026
# Epoch 2/100
# 1/1 [==============================] - 0s 8ms/step - loss: 0.2484
# Epoch 3/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.2104
# Epoch 4/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1848
# Epoch 5/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1671
# Epoch 6/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.1536
# Epoch 7/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1421
# Epoch 8/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1322
# Epoch 9/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.1242
# Epoch 10/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1175
# Epoch 11/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.1113
# Epoch 12/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.1053
# Epoch 13/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0994
# Epoch 14/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0934
# Epoch 15/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0875
# Epoch 16/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0817
# Epoch 17/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0762
# Epoch 18/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0709
# Epoch 19/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0655
# Epoch 20/100
# 1/1 [==============================] - 0s 28ms/step - loss: 0.0598
# Epoch 21/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0537
# Epoch 22/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0475
# Epoch 23/100
# 1/1 [==============================] - 0s 24ms/step - loss: 0.0415
# Epoch 24/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0360
# Epoch 25/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0314
# Epoch 26/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0280
# Epoch 27/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0257
# Epoch 28/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0244
# Epoch 29/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0238
# Epoch 30/100
# 1/1 [==============================] - 0s 27ms/step - loss: 0.0233
# Epoch 31/100
# 1/1 [==============================] - 0s 30ms/step - loss: 0.0223
# Epoch 32/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0208
# Epoch 33/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0188
# Epoch 34/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0166
# Epoch 35/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0147
# Epoch 36/100
# 1/1 [==============================] - 0s 16ms/step - loss: 0.0131
# Epoch 37/100
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0119
# Epoch 38/100
# 1/1 [==============================] - 0s 21ms/step - loss: 0.0110
# Epoch 39/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0103
# Epoch 40/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0097
# Epoch 41/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0091
# Epoch 42/100
# 1/1 [==============================] - 0s 17ms/step - loss: 0.0084
# Epoch 43/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0077
# Epoch 44/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0070
# Epoch 45/100
# 1/1 [==============================] - 0s 11ms/step - loss: 0.0062
# Epoch 46/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0053
# Epoch 47/100
# 1/1 [==============================] - 0s 19ms/step - loss: 0.0044
# Epoch 48/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0037
# Epoch 49/100
# 1/1 [==============================] - 0s 12ms/step - loss: 0.0031
# Epoch 50/100
# 1/1 [==============================] - 0s 26ms/step - loss: 0.0027
# Epoch 51/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0025
# Epoch 52/100
# 1/1 [==============================] - 0s 23ms/step - loss: 0.0023
# Epoch 53/100
# 1/1 [==============================] - 0s 18ms/step - loss: 0.0021
# Epoch 54/100
# 1/1 [==============================] - 0s 20ms/step - loss: 0.0019
# Epoch 55/100
# 1/1 [==============================] - 0s 22ms/step - loss: 0.0016
# Epoch 56/100
# 1/1 [==============================] - 0s 13ms/step - loss: 0.0014
# Epoch 57/100
# 1/1 [==============================] - 0s 15ms/step - loss: 0.0012
# Epoch 58/100
# 1/1 [==============================] - 0s 17ms/step - loss: 9.9395e-04
# Epoch 59/100
# 1/1 [==============================] - 0s 18ms/step - loss: 8.4495e-04
# Epoch 60/100
# 1/1 [==============================] - 0s 17ms/step - loss: 7.3055e-04
# Epoch 61/100
# 1/1 [==============================] - 0s 18ms/step - loss: 6.7054e-04
# Epoch 62/100
# 1/1 [==============================] - 0s 20ms/step - loss: 6.3302e-04
# Epoch 63/100
# 1/1 [==============================] - 0s 29ms/step - loss: 5.7908e-04
# Epoch 64/100
# 1/1 [==============================] - 0s 18ms/step - loss: 5.2067e-04
# Epoch 65/100
# 1/1 [==============================] - 0s 28ms/step - loss: 4.5962e-04
# Epoch 66/100
# 1/1 [==============================] - 0s 21ms/step - loss: 3.9863e-04
# Epoch 67/100
# 1/1 [==============================] - 0s 19ms/step - loss: 3.5351e-04
# Epoch 68/100
# 1/1 [==============================] - 0s 23ms/step - loss: 3.1308e-04
# Epoch 69/100
# 1/1 [==============================] - 0s 30ms/step - loss: 2.6957e-04
# Epoch 70/100
# 1/1 [==============================] - 0s 16ms/step - loss: 2.3672e-04
# Epoch 71/100
# 1/1 [==============================] - 0s 11ms/step - loss: 2.1073e-04
# Epoch 72/100
# 1/1 [==============================] - 0s 24ms/step - loss: 1.8414e-04
# Epoch 73/100
# 1/1 [==============================] - 0s 29ms/step - loss: 1.6110e-04
# Epoch 74/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.3947e-04
# Epoch 75/100
# 1/1 [==============================] - 0s 20ms/step - loss: 1.2298e-04
# Epoch 76/100
# 1/1 [==============================] - 0s 18ms/step - loss: 1.1746e-04
# Epoch 77/100
# 1/1 [==============================] - 0s 24ms/step - loss: 1.1501e-04
# Epoch 78/100
# 1/1 [==============================] - 0s 21ms/step - loss: 1.0921e-04
# Epoch 79/100
# 1/1 [==============================] - 0s 22ms/step - loss: 9.6924e-05
# Epoch 80/100
# 1/1 [==============================] - 0s 20ms/step - loss: 7.8430e-05
# Epoch 81/100
# 1/1 [==============================] - 0s 17ms/step - loss: 6.4016e-05
# Epoch 82/100
# 1/1 [==============================] - 0s 11ms/step - loss: 5.7260e-05
# Epoch 83/100
# 1/1 [==============================] - 0s 16ms/step - loss: 5.5185e-05
# Epoch 84/100
# 1/1 [==============================] - 0s 19ms/step - loss: 5.5895e-05
# Epoch 85/100
# 1/1 [==============================] - 0s 18ms/step - loss: 5.4749e-05
# Epoch 86/100
# 1/1 [==============================] - 0s 18ms/step - loss: 5.1383e-05
# Epoch 87/100
# 1/1 [==============================] - 0s 26ms/step - loss: 4.7289e-05
# Epoch 88/100
# 1/1 [==============================] - 0s 17ms/step - loss: 4.1325e-05
# Epoch 89/100
# 1/1 [==============================] - 0s 18ms/step - loss: 3.5290e-05
# Epoch 90/100
# 1/1 [==============================] - 0s 18ms/step - loss: 3.0019e-05
# Epoch 91/100
# 1/1 [==============================] - 0s 27ms/step - loss: 2.6157e-05
# Epoch 92/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.5042e-05
# Epoch 93/100
# 1/1 [==============================] - 0s 21ms/step - loss: 2.4655e-05
# Epoch 94/100
# 1/1 [==============================] - 0s 12ms/step - loss: 2.3614e-05
# Epoch 95/100
# 1/1 [==============================] - 0s 22ms/step - loss: 2.1192e-05
# Epoch 96/100
# 1/1 [==============================] - 0s 12ms/step - loss: 1.7338e-05
# Epoch 97/100
# 1/1 [==============================] - 0s 17ms/step - loss: 1.4040e-05
# Epoch 98/100
# 1/1 [==============================] - 0s 18ms/step - loss: 1.1781e-05
# Epoch 99/100
# 1/1 [==============================] - 0s 18ms/step - loss: 1.0595e-05
# Epoch 100/100
# 1/1 [==============================] - 0s 13ms/step - loss: 1.0291e-05

# %%
# Predict future values
forecast_rnn = model.predict(X_test)

# Denormalize the forecasted values
forecast_denormalized = forecast_rnn * std + mean
y_test_denormalized = y_test * std + mean

# Use the same index for plotting (so both y_test and forecast align)
time_index = temperature_df_hourly.index[-len(y_test):]
# Out:
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fb70739db80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 111ms/step

# %%
# Plot actual vs predicted values
plt.plot(time_index, y_test_denormalized, label='Actual')
plt.plot(time_index, forecast_denormalized, label='Predicted')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add labels and legend
plt.xlabel('Date')
plt.ylabel('Temperature')
plt.title('SimpleRNN - Actual vs Predicted Temperature')

plt.legend()

plt.tight_layout()
plt.show()

# %%
# Calculate metrics
mae_rnn = mean_absolute_error(y_test_denormalized, forecast_denormalized)
mse_rnn = mean_squared_error(y_test_denormalized, forecast_denormalized)
mape_rnn = mean_absolute_percentage_error(y_test_denormalized, forecast_denormalized)
print(f"SimpleRNN - MAE: {mae_rnn}, MSE: {mse_rnn}, MAPE: {mape_rnn}")
# Out:
# SimpleRNN - MAE: 0.36070061854901986, MSE: 0.18058275920454095, MAPE: 0.013332196163031284
